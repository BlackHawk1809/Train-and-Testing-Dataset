# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("H://6th Semester//Data Analysis//Knight ML Assignment//Knight ML Assignment//Data//train.csv")

# %%
df
# Out:
#            user_name    country  \
# 0                NaN  Australia
# 1      @wawinereport         US
# 2                NaN      Italy
# 3         @vossroger     France
# 4         @vossroger     France
# ...              ...        ...
# 82652    @wineschach      Spain
# 82653            NaN         US
# 82654     @vossroger     France
# 82655     @vossroger     France
# 82656            NaN         US
#
#                                             review_title  \
# 0      Andrew Peace 2007 Peace Family Vineyard Chardo...
# 1      North by Northwest 2014 Red (Columbia Valley (...
# 2                      Renato Ratti 2007 Conca  (Barolo)
# 3      Domaine l'Ancienne Cure 2010 L'Abbaye White (B...
# 4      Château du Cèdre 2012 Le Cèdre Vintage Malbec ...
# ...                                                  ...
# 82652                   Montecillo 2007 Crianza  (Rioja)
# 82653  Vivác Winery 2008 Single Vineyard Cabernet Sau...
# ...

# %%
df.isnull().sum()
# Out:
# user_name             19393
# country                  35
# review_title              0
# review_description        0
# designation           23647
# points                    0
# price                  5569
# province                 35
# region_1              12754
# region_2              46708
# winery                    0
# variety                   0
# dtype: int64

# %%
before_rows = df.shape[0]
print(before_rows)
# Out:
# 82657

# %%
df = df.dropna()
after_rows = df.shape[0]
print(after_rows)
# Out:
# 15986

# %%
before_rows - after_rows
# Out:
# 66671

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df
# Out:
#               user_name country  \
# 6         @wawinereport      US
# 7               @vboone      US
# 8           @paulgwine       US
# 10              @vboone      US
# 34          @paulgwine       US
# ...                 ...     ...
# 82630           @vboone      US
# 82632           @vboone      US
# 82639       @paulgwine       US
# 82641  @gordone_cellars      US
# 82642           @vboone      US
#
#                                             review_title  \
# 6      Gordon Estate 2012 Tradition Red (Columbia Val...
# 7      Rock Wall 2014 Monte Rosso Reserve Zinfandel (...
# 8      Elizabeth Chambers 2014 Falcon Glen Vineyard P...
# 10     Cuvaison 2014 Estate Grown Sauvignon Blanc (Ca...
# 34           Durant 2013 Raven Chardonnay (Dundee Hills)
# ...                                                  ...
# 82630  Yorkville Cellars 2010 Randle Hill Vineyard Sa...
# 82632            un4seen 2009 Red blend Red (California)
# ...

# %%
plt.scatter(df['points'],df['price'])

# %%
df.drop(['user_name','country','review_title','review_description','designation','winery','region_2'],axis=1)
# Out:
#        points  price    province              region_1                variety
# 6          91   45.0  Washington  Columbia Valley (WA)              Red Blend
# 7          90   50.0  California         Sonoma County              Zinfandel
# 8          91   48.0      Oregon           McMinnville             Pinot Noir
# 10         90   18.0  California              Carneros        Sauvignon Blanc
# 34         92   25.0      Oregon          Dundee Hills             Chardonnay
# ...       ...    ...         ...                   ...                    ...
# 82630      88   18.0  California   Yorkville Highlands        Sauvignon Blanc
# 82632      85   10.0  California            California              Red Blend
# 82639      92   85.0      Oregon          Dundee Hills             Pinot Noir
# 82641      92   36.0  California             El Dorado  Rhône-style Red Blend
# 82642      86   25.0  California              Carneros             Pinot Noir
#
# [15986 rows x 5 columns]

# %%
pd.value_counts(df['user_name'])
# Out:
# @vboone             4683
# @paulgwine          4396
# @mattkettmann       3122
# @wawinereport       2373
# @gordone_cellars    1257
# @suskostrzewa         68
# @JoeCz                45
# @wineschach           32
# @laurbuzz              8
# @winewchristina        1
# @vossroger             1
# Name: user_name, dtype: int64

# %%
df.apply(pd.value_counts).fillna(0)
# Out:
#                                                     user_name  country  \
# 4.0                                                       0.0      0.0
# 5.0                                                       0.0      0.0
# 7.0                                                       0.0      0.0
# 8.0                                                       0.0      0.0
# 9.0                                                       0.0      0.0
# ...                                                       ...      ...
# étoile Brut                                               0.0      0.0
# étoile Rosé                                               0.0      0.0
# ‘S'                                                       0.0      0.0
# “Califa” is a Native American word meaning the ...        0.0      0.0
# “No oak/No malo” the label proclaims, as if to ...        0.0      0.0
#
#                                                     review_title  \
# ...

# %%
df['user_name'].unique()
# Out:
# array(['@wawinereport', '@vboone', '@paulgwine\xa0', '@mattkettmann',
#        '@gordone_cellars', '@suskostrzewa', '@JoeCz', '@wineschach',
#        '@laurbuzz', '@winewchristina', '@vossroger'], dtype=object)

# %%
username = {'@wawinereport':1, '@vboone':2, '@paulgwine\xa0':3, '@mattkettmann':4,
       '@gordone_cellars':5, '@suskostrzewa':6, '@JoeCz':7, '@wineschach':8,
       '@laurbuzz':9, '@winewchristina':10, '@vossroger':11}

# %%
df['user_name']=df['user_name'].map(username)
# Out:
# c:\users\hp-p\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df['user_name']
# Out:
# 6        1
# 7        2
# 8        3
# 10       2
# 34       3
#         ..
# 82630    2
# 82632    2
# 82639    3
# 82641    5
# 82642    2
# Name: user_name, Length: 15986, dtype: int64

# %%
df
# Out:
#        user_name country                                       review_title  \
# 6              1      US  Gordon Estate 2012 Tradition Red (Columbia Val...
# 7              2      US  Rock Wall 2014 Monte Rosso Reserve Zinfandel (...
# 8              3      US  Elizabeth Chambers 2014 Falcon Glen Vineyard P...
# 10             2      US  Cuvaison 2014 Estate Grown Sauvignon Blanc (Ca...
# 34             3      US        Durant 2013 Raven Chardonnay (Dundee Hills)
# ...          ...     ...                                                ...
# 82630          2      US  Yorkville Cellars 2010 Randle Hill Vineyard Sa...
# 82632          2      US            un4seen 2009 Red blend Red (California)
# 82639          3      US  Archery Summit 2012 Red Hills Estate Pinot Noi...
# 82641          5      US  The Withers Winery 2013 Mr. Burgess Red (El Do...
# 82642          2      US  Peter Cellars 2013 Estate Rosé of Pinot Noir (...
#
# ...

# %%
df['country'].unique()
# Out:
# array(['US'], dtype=object)

# %%
country = {'US':12}

# %%
df['country'] = df['country'].map(country)
# Out:
# c:\users\hp-p\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df['country']
# Out:
# 6        12
# 7        12
# 8        12
# 10       12
# 34       12
#          ..
# 82630    12
# 82632    12
# 82639    12
# 82641    12
# 82642    12
# Name: country, Length: 15986, dtype: int64

# %%
df['variety'].unique()
# Out:
# array(['Red Blend', 'Zinfandel', 'Pinot Noir', 'Sauvignon Blanc',
#        'Chardonnay', 'Bordeaux-style Red Blend', 'Syrah',
#        'Rhône-style Red Blend', 'Sangiovese', 'Merlot',
#        'Cabernet Sauvignon', 'Sparkling Blend', 'Rosé', 'Malbec',
#        'Riesling', 'Cabernet Franc', 'White Blend', 'Tempranillo',
#        'Grüner Veltliner', 'Bordeaux-style White Blend', 'Pinot Gris',
#        'Gewürztraminer', 'Nebbiolo', 'Pinot Grigio', 'Champagne Blend',
#        'Gamay'], dtype=object)

# %%
variety = {'Red Blend':1, 'Zinfandel':2, 'Pinot Noir':3, 'Sauvignon Blanc':4,
       'Chardonnay':5, 'Bordeaux-style Red Blend':6, 'Syrah':7,
       'Rhône-style Red Blend':8, 'Sangiovese':9, 'Merlot':10,
       'Cabernet Sauvignon':11, 'Sparkling Blend':12, 'Rosé':13, 'Malbec':14,
       'Riesling':18, 'Cabernet Franc':17, 'White Blend':16, 'Tempranillo':15,
       'Grüner Veltliner':19, 'Bordeaux-style White Blend':20, 'Pinot Gris':21,
       'Gewürztraminer':25, 'Nebbiolo':24, 'Pinot Grigio':23, 'Champagne Blend':22,
       'Gamay':26}

# %%
df['variety'] = df['variety'].map(variety)
# Out:
# c:\users\hp-p\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df['variety']
# Out:
# 6        1
# 7        2
# 8        3
# 10       4
# 34       5
#         ..
# 82630    4
# 82632    1
# 82639    3
# 82641    8
# 82642    3
# Name: variety, Length: 15986, dtype: int64

# %%
df['region_1'].unique()
# Out:
# array(['Columbia Valley (WA)', 'Sonoma County', 'McMinnville', 'Carneros',
#        'Dundee Hills', 'North Coast', 'Happy Canyon of Santa Barbara',
#        'Knights Valley', 'Santa Barbara County',
#        'Walla Walla Valley (OR)', 'Livermore Valley',
#        'Russian River Valley', 'California', 'Diamond Mountain District',
#        'Fiddletown', 'Napa Valley', 'Chehalem Mountains', 'Washington',
#        'Eola-Amity Hills', 'Arroyo Grande Valley', 'Willamette Valley',
#        'Santa Ynez Valley', 'Dry Creek Valley', 'Adelaida District',
#        'Santa Maria Valley', 'Alexander Valley', 'Santa Cruz Mountains',
#        'Walla Walla Valley (WA)', 'Paso Robles', 'Horse Heaven Hills',
#        'Monterey County', 'Sta. Rita Hills', 'Yakima Valley',
#        'Sonoma Valley', 'Central Coast', 'Finger Lakes', 'Ribbon Ridge',
#        'Green Valley', 'Wahluke Slope', 'Red Mountain', 'Temecula Valley',
#        'Sonoma Mountain', 'Mount Veeder', 'Rogue Valley', 'Lodi',
# ...

# %%
region_1 = { 'Columbia Valley (WA)':1, 'Sonoma County':2, 'McMinnville':3, 'Carneros':4,
       'Dundee Hills':7, 'North Coast':6, 'Happy Canyon of Santa Barbara':5,
       'Knights Valley':8, 'Santa Barbara County':9,
       'Walla Walla Valley (OR)':11, 'Livermore Valley':10,
       'Russian River Valley':12, 'California':13, 'Diamond Mountain District':14,
       'Fiddletown':19, 'Napa Valley':18, 'Chehalem Mountains':17, 'Washington':16,
       'Eola-Amity Hills':20, 'Arroyo Grande Valley':21, 'Willamette Valley':22,
       'Santa Ynez Valley':25, 'Dry Creek Valley':24, 'Adelaida District':23,
       'Santa Maria Valley':26, 'Alexander Valley':27, 'Santa Cruz Mountains':28,
       'Walla Walla Valley (WA)':15, 'Paso Robles':30, 'Horse Heaven Hills':29,
       'Monterey County':33, 'Sta. Rita Hills':32, 'Yakima Valley':31,
       'Sonoma Valley':34, 'Central Coast':35, 'Finger Lakes':36, 'Ribbon Ridge':37,
       'Green Valley':41, 'Wahluke Slope':40, 'Red Mountain':39, 'Temecula Valley':38,
       'Sonoma Mountain':42, 'Mount Veeder':43, 'Rogue Valley':44, 'Lodi':45,
       'Sierra Foothills':48, 'Sonoma Coast':47, 'North Fork of Long Island':46,
       'San Luis Obispo County':49, 'Oakville':50, 'Arroyo Seco':51,
       'Mokelumne River':53, 'Moon Mountain District Sonoma County':52,
       'Amador County':54, 'Oregon':55, 'River Junction':56, 'Edna Valley':57,
       'Dunnigan Hills':60, 'Atlas Peak':59, 'Santa Lucia Highlands':58,
       'St. Helena':61, 'Fair Play':62, 'Alta Mesa':63, 'Shenandoah Valley (CA)':64,
       'South Coast':67, 'Umpqua Valley':66, 'Ben Lomond Mountain':65,
       'Santa Clara Valley':68, 'Rutherford':69, 'Columbia Valley (OR)':70,
       'Clarksburg':74, 'Southern Oregon':73, 'El Dorado':72, 'San Benito County':71,
       'Lake Chelan':75, 'Carmel Valley':76, 'Santa Barbara':77, 'Calistoga':78,
       'Paicines':83, 'Monterey':82, 'Fort Ross-Seaview':81, 'Columbia Gorge (OR)':80,
       'Elkton Oregon':84, 'San Antonio Valley':85, 'Chalk Hill':86,
       'Chiles Valley':90, 'Yolo County':89, 'Snipes Mountain':88, 'Yountville':87,
       'Napa County':91, 'Naches Heights':92, 'Ancient Lakes':93, 'Mt. Harlan':94,
       'Calaveras County':95, 'Mendocino-Lake':96, 'San Bernabe':97, 'Rockpile':98,
       'Contra Costa County':101, 'Nevada County':100, 'Columbia Gorge (WA)':99,
       'Stags Leap District':102, 'Cienega Valley':103, 'Oak Knoll District':104,
       'Chalone':106, 'El Dorado County':105, 'Ballard Canyon':106,
       'Templeton Gap District':107, 'San Francisco Bay':108, 'Humboldt County':109,
       'Spring Mountain District':111, 'Applegate Valley':110,
       'San Francisco Bay-Livermore Valley':112,
       'Paso Robles Willow Creek District':115, 'Marin County':113,
       'Pine Mountain-Cloverdale Peak':116, 'Rattlesnake Hills':114,
       'Howell Mountain':117, 'Sonoma County-Monterey County':118,
       'Sonoma County-Napa County':120, 'Yorkville Highlands':119,
       'Carneros-Napa Valley':122, 'Madera':121, 'Solano County':123,
       'Bennett Valley':126, 'Cucamonga Valley':125, 'Coombsville':124,
       'Sonoma County-Monterey County-Napa County':127, 'Northern Sonoma':128,
       'Chelan County':131, 'Clements Hills':130, 'Los Carneros':129,
       'Monterey County-Napa County-Sonoma County':132, 'Malibu Coast':133,
       'New York':137, 'El Pomar District':136, 'Long Island':135, 'Ramona Valley':134,
       'Ventura County':138, 'San Luis Obispo':139, 'Sonoma-Napa':140,
       'Placer County':142, 'Columbia Valley-Walla Walla Valley':141,
       'Napa County-Sonoma County-Lake County':143, 'Hudson River Region':144,
       'Napa County-Sonoma County':146, 'Yamhill County':145,
       'Sonoma County-San Joaquin County':147, 'Temecula':148, 'Napa-Carneros':149,
       'San Diego County':152, 'Santa Clara County':151, 'Cayuga Lake':150,
       'Saddle Rock-Malibu':153,
       'Napa County-Sonoma County-San Joaquin County':154,
       'Sonoma County-Monterey County-Santa Barbara County':155,
       'The Hamptons, Long Island':157, 'Sonoma County-Lake County':156,
       'Suisun Valley':160, 'York Mountain':158, 'Sonoma-Napa-Lake':159,
       'Capay Valley':161, 'Tehama County':162, 'Santa Margarita Ranch':163,
       'Malibu-Newton Canyon':164, 'Tuolumne County':165}

# %%
df['region_1'] = df['region_1'].map(region_1)
# Out:
# c:\users\hp-p\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df['region_1']
# Out:
# 6          1
# 7          2
# 8          3
# 10         4
# 34         7
#         ...
# 82630    119
# 82632     13
# 82639      7
# 82641     72
# 82642      4
# Name: region_1, Length: 15986, dtype: int64

# %%
df['province'].unique()
# Out:
# array(['Washington', 'California', 'Oregon', 'New York'], dtype=object)

# %%
province = {'Washington':101, 'California':102, 'Oregon':103, 'New York':104}

# %%
df['province']= df['province'].map(province)
# Out:
# c:\users\hp-p\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df['province']
# Out:
# 6        101
# 7        102
# 8        103
# 10       102
# 34       103
#         ...
# 82630    102
# 82632    102
# 82639    103
# 82641    102
# 82642    102
# Name: province, Length: 15986, dtype: int64

# %%
X = df[['region_1','province','points','user_name']]

# %%
y = df[['price',]]

# %%
from sklearn.linear_model import LinearRegression
clf = LinearRegression()

# %%
X_train , X_test , y_train , y_test = train_test_split(X,y,train_size=0.2)

# %%
clf.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
clf.predict(X_test)
# Out:
# array([[26.50778929],
#        [51.01077811],
#        [57.10920935],
#        ...,
#        [36.71327092],
#        [45.77761278],
#        [40.48219942]])

# %%
y_test
# Out:
#        price
# 44166   28.0
# 26425   70.0
# 2645    33.0
# 3143    11.0
# 26999   40.0
# ...      ...
# 63534    8.0
# 13719   20.0
# 1549    16.0
# 32717   65.0
# 18047   28.0
#
# [12789 rows x 1 columns]

# %%
clf.score(X_test,y_test)
# Out:
# 0.16257543248682338
